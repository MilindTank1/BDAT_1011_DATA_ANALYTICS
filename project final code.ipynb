# %%
import warnings
from termcolor import colored
warnings.filterwarnings("ignore")
import bs4 # library for pulling data out of HTML and XML files.
import requests
from googlesearch import search
import webbrowser #To open the link 
query_1 = input("Enter 1st Artist: ")
dotcom_1 = ".com"
query_dot_com_1 = query_1+dotcom_1
query_2 = input("Enter  2nd Artist: ")
dotcom_2 = ".com"
query_dot_com_2 = query_2+dotcom_2
print()
print(colored('Official website', attrs=['bold']))

for i in search(query_dot_com_1, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
    url = i
for i in search(query_dot_com_2, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
    url = i
print()
#########################################################
print(colored('Twitter', 'cyan', attrs=['bold']))
print(colored('Artist 1:', attrs=['bold']))
Twitter = "Twitter official"
substring = "?"
query_Twitter_1 = query_1+Twitter
for i in search(query_Twitter_1, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
username_Twitter_1=i.split('/')[-1]
head_username_Twitter_1, sep, tail = username_Twitter_1.partition('?')
print('Twitter id: ',head_username_Twitter_1)
username_Twitter_1 = head_username_Twitter_1

print(colored('Artist 2:', attrs=['bold']))
Twitter = "Twitter official"
substring = "?"
query_Twitter_2 = query_2+Twitter
for i in search(query_Twitter_2, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
username_Twitter_2=i.split('/')[-1]
head_username_Twitter_2, sep, tail = username_Twitter_2.partition('?')

print('Twitter id: ',head_username_Twitter_2)
username_Twitter_2 = head_username_Twitter_2


print()
#########################################################
print(colored('Youtube', 'red', attrs=['bold']))
print(colored('Artist 1:',attrs=['bold']))
Youtube = "Youtube"
query_Youtube_1 = query_1+Youtube
for i in search(query_Youtube_1, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
username_Youtube_1=i.split('/')[-1]
print('Youtube id: ',username_Youtube_1)

print(colored('Artist 2:',attrs=['bold']))
Youtube = "Youtube"
query_Youtube_2 = query_2+Youtube
for i in search(query_Youtube_2, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
username_Youtube_2=i.split('/')[-1]
print('Youtube id: ',username_Youtube_2)
print()
#########################################################
print(colored('Spotify', 'green', attrs=['bold']))
print(colored('Artist 1:',attrs=['bold']))
Spotify = "Spotify"
query_Spotify_1 = query_1+Spotify
for i in search(query_Spotify_1, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
username_Spotify_1=i.split('/')[-1]
print('Spotify id: ',username_Spotify_1)

print(colored('Artist 2:',attrs=['bold']))
Spotify = "Spotify"
query_Spotify_2 = query_2+Spotify
for i in search(query_Spotify_2, tld="com", num=1, stop=1, pause=2): #TLD=com -> top level domain
    print(i)
username_Spotify_2=i.split('/')[-1]
print('Spotify id: ',username_Spotify_2)
# Out:
# Enter 1st Artist: charlie puth
# Enter  2nd Artist: afrojack
#
# Official website
# https://www.charlieputh.com/
# https://afrojack.com/
#
# Twitter
# Artist 1:
# https://twitter.com/charlieputh
# Twitter id:  charlieputh
# Artist 2:
# https://twitter.com/afrojack?lang=en
# Twitter id:  afrojack
#
# Youtube
# Artist 1:
# https://www.youtube.com/channel/UCwppdrjsBPAZg5_cUwQjfMQ
# Youtube id:  UCwppdrjsBPAZg5_cUwQjfMQ
# Artist 2:
# https://www.youtube.com/channel/UCmKm7HJdOfkWLyml-fzKlVg
# Youtube id:  UCmKm7HJdOfkWLyml-fzKlVg
#
# Spotify
# Artist 1:
# https://open.spotify.com/artist/6VuMaDnrHyPL1p4EHjYLi7
# Spotify id:  6VuMaDnrHyPL1p4EHjYLi7
# Artist 2:
# https://open.spotify.com/artist/4D75GcNG95ebPtNvoNVXhz
# Spotify id:  4D75GcNG95ebPtNvoNVXhz

# %%
#Twitter metric for Artist 1
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

Twitter_consumer_key = '0AdD8gRrY5KKUJAgrqcJ76XDE'  # Use your own key. To get a key https://apps.twitter.com/
Twitter_consumer_secret = 'Zu8ZmDvqPPnS9Q5EihIVsMwdIsAKWeMUimrWQwbaCWkjpaI6PP'
Twitter_access_token = '1536873952752041984-IgzzzLE3UtP0hUNoz0I6Ti0VRNgPV4'
Twitter_access_secret = '142ddxWGEi2qoFp43ItUS9iHRtsAJJz8rChw6CUFUq4GW'
Twitter_Bearer_Token = 'AAAAAAAAAAAAAAAAAAAAAJnheAEAAAAAEG58cHm%2BDHbWEwFk%2FKFTCLH4EJM%3Dp0EyOHCMk8lnNuTisD2aqd6w9J9hp2t0npQM0aQohA3n5ktJqU'


auth = OAuthHandler(Twitter_consumer_key, Twitter_consumer_secret)
auth.set_access_token(Twitter_access_token, Twitter_access_secret)


twitter = tweepy.Client(bearer_token=Twitter_Bearer_Token)


follower_1 = twitter.get_user(username=username_Twitter_1, user_fields=["public_metrics"]).data.public_metrics['followers_count']
numbers_1 = "{:,}".format(follower_1)


api = tweepy.API(auth)

tweets = api.user_timeline(screen_name=username_Twitter_1, count=30)

likes_1 = 0 
retweets_1 = 0  

for tweet in tweets:   


    likes_1 += tweet.favorite_count  #Likes on the last 30 tweets
    retweets_1 += tweet.retweet_count  #Retweets on the last 30 tweets

# %%
#Twitter metric for Artist 2
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

Twitter_consumer_key = '0AdD8gRrY5KKUJAgrqcJ76XDE'  # Use your own key. To get a key https://apps.twitter.com/
Twitter_consumer_secret = 'Zu8ZmDvqPPnS9Q5EihIVsMwdIsAKWeMUimrWQwbaCWkjpaI6PP'
Twitter_access_token = '1536873952752041984-IgzzzLE3UtP0hUNoz0I6Ti0VRNgPV4'
Twitter_access_secret = '142ddxWGEi2qoFp43ItUS9iHRtsAJJz8rChw6CUFUq4GW'
Twitter_Bearer_Token = 'AAAAAAAAAAAAAAAAAAAAAJnheAEAAAAAEG58cHm%2BDHbWEwFk%2FKFTCLH4EJM%3Dp0EyOHCMk8lnNuTisD2aqd6w9J9hp2t0npQM0aQohA3n5ktJqU'


auth = OAuthHandler(Twitter_consumer_key, Twitter_consumer_secret)
auth.set_access_token(Twitter_access_token, Twitter_access_secret)


twitter = tweepy.Client(bearer_token=Twitter_Bearer_Token)

follower_2 = twitter.get_user(username=username_Twitter_2, user_fields=["public_metrics"]).data.public_metrics['followers_count']
numbers_2 = "{:,}".format(follower_2)

api = tweepy.API(auth)

tweets = api.user_timeline(screen_name=username_Twitter_2, count=30)

likes_2 = 0 
retweets_2 = 0  

for tweet in tweets:   


    likes_2 += tweet.favorite_count  #Likes on the last 30 tweets
    retweets_2 += tweet.retweet_count  #Retweets on the last 30 tweets

# %%
import requests
import json
youtube_API_KEY = "AIzaSyAMV_PfLecSg3zf2Pm5lTmMlU6i-bnSWRo"


# Youtube metrics for artist 1
youtube_url_1 = f'https://www.googleapis.com/youtube/v3/channels?part=statistics&id={username_Youtube_1}&key={youtube_API_KEY}'
json_url_1 = requests.get(youtube_url_1)
data_1 = json.loads(json_url_1.text)

try:
        data_1 = data_1["items"][0]["statistics"]
except:
        data_1 = None
        elf.channel_statistics = data_1

views_1=data_1['viewCount']
subcount_1=data_1['subscriberCount']
vidcount_1=data_1['videoCount']


# Youtube metrics for artist 2
youtube_url_2 = f'https://www.googleapis.com/youtube/v3/channels?part=statistics&id={username_Youtube_2}&key={youtube_API_KEY}'
json_url_2 = requests.get(youtube_url_2)
data_2 = json.loads(json_url_2.text)

try:
        data_2 = data_2["items"][0]["statistics"]
except:
        data_2 = None
        elf.channel_statistics = data_2


views_2=data_2['viewCount']
subcount_2=data_2['subscriberCount']
vidcount_2=data_2['videoCount']

# %%
#Spotify metric for Artist 1

import requests

Spotify_CLIENT_ID = '804463d1343642ae8c56e1f06d50c366'
Spotify_CLIENT_SECRET = 'c6e38ac3c605420f824a6748994311b3'

AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': Spotify_CLIENT_ID,
    'client_secret': Spotify_CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

#find info about artist

artist_id_1 = username_Spotify_1

r = requests.get(BASE_URL + 'artists/' + artist_id_1, 
                 headers=headers)
                 #params={'include_groups': 'artists', 'limit': 50})
d = r.json()
genre_1 = d['genres']
name_1 = d['name']
popularity_1 = d['popularity']

# %%
#Spotify metric for Artist 2

import requests

Spotify_CLIENT_ID = '804463d1343642ae8c56e1f06d50c366'
Spotify_CLIENT_SECRET = 'c6e38ac3c605420f824a6748994311b3'

AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': Spotify_CLIENT_ID,
    'client_secret': Spotify_CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

#find info about artist

artist_id_2 = username_Spotify_2

r = requests.get(BASE_URL + 'artists/' + artist_id_2, 
                 headers=headers)
                 #params={'include_groups': 'artists', 'limit': 50})
d = r.json()
genre_2 = d['genres']
name_2 = d['name']
popularity_2 = d['popularity']

# %%
#Artist 1

print(f'Twitter metrics for: {username_Twitter_1}\n')

print('number of followers:',follower_1)
print("Likes =",likes_1)  
print("Retweets =",retweets_1)
print()

print('Youtube Metrics for',username_Youtube_1)
print("Views:",views_1)
print("Subscribers:",subcount_1)
print("Total Videos:",vidcount_1)
print()

print('Spotify metric for',username_Spotify_1)
print('Genre:',genre_1)
print('name:',name_1)
print('popularity:',popularity_1)
print()


#Artist 2
print(f'Twitter metrics for: {username_Twitter_2}\n')

print('number of followers:',follower_2)
print("Likes =",likes_2)  
print("Retweets =",retweets_2)
print()

print('Youtube Metrics for',username_Youtube_2)
print("Views:",views_2)
print("Subscribers:",subcount_2)
print("Total Videos:",vidcount_2)
print()

print('Spotify metric for',username_Spotify_2)
print('Genre:',genre_2)
print('name:',name_2)
print('popularity:',popularity_2)
# Out:
# Twitter metrics for: charlieputh
#
# number of followers: 3491974
# Likes = 1155076
# Retweets = 139951
#
# Youtube Metrics for UCwppdrjsBPAZg5_cUwQjfMQ
# Views: 8548996275
# Subscribers: 20600000
# Total Videos: 132
#
# Spotify metric for 6VuMaDnrHyPL1p4EHjYLi7
# Genre: ['dance pop', 'pop', 'viral pop']
# name: Charlie Puth
# popularity: 83
#
# Twitter metrics for: afrojack
#
# number of followers: 2536650
# Likes = 5328
# Retweets = 2374
#
# Youtube Metrics for UCmKm7HJdOfkWLyml-fzKlVg
# Views: 756125347
# Subscribers: 2530000
# Total Videos: 401
#
# Spotify metric for 4D75GcNG95ebPtNvoNVXhz
# Genre: ['big room', 'dance pop', 'dutch house', 'edm', 'electro house', 'pop dance', 'pop rap', 'progressive house', 'tropical house']
# name: Afrojack
# popularity: 72

# %%
name_for_graph = name_1,name_2
name_for_graph
# Out:
# ('Charlie Puth', 'Afrojack')

# %%
#Creating dataframe
import pandas as pd
import numpy as np
df = pd.DataFrame(np.array([[name_1,follower_1,likes_1,retweets_1,genre_1,popularity_1,views_1,subcount_1,vidcount_1],[name_2,follower_2,likes_2,retweets_2,genre_2,popularity_2,views_2,subcount_2,vidcount_2]]),columns=['Artist Name','Twitter Followers','Twitter Likes','Twitter ReTweets','Genre','Popularity','Youtube Views','Youtube Subscribers','Youtube videos'])
df
# Out:
#     Artist Name Twitter Followers Twitter Likes Twitter ReTweets  \
# 0  Charlie Puth           3491974       1155076           139951
# 1      Afrojack           2536650          5328             2374
#
#                                                Genre Popularity Youtube Views  \
# 0                        [dance pop, pop, viral pop]         83    8548996275
# 1  [big room, dance pop, dutch house, edm, electr...         72     756125347
#
#   Youtube Subscribers Youtube videos
# 0            20600000            132
# 1             2530000            401

# %%
df1=df.drop(columns=['Artist Name','Genre'])
df1
# Out:
#   Twitter Followers Twitter Likes Twitter ReTweets Popularity Youtube Views  \
# 0           3491974       1155076           139951         83    8548996275
# 1           2536650          5328             2374         72     756125347
#
#   Youtube Subscribers Youtube videos
# 0            20600000            132
# 1             2530000            401

# %%
import matplotlib.pyplot as plt 
ax = df1.plot.bar(subplots=True, figsize=(10,30),legend = False)
plt.xlabel("Artist")
plt.show()

# %%
from wordcloud import WordCloud

text3 = ' '.join(df['Genre'].astype(str))
wordcloud2 = WordCloud(width=1600, height=800,background_color='white',collocations=False).generate(text3)
# Generate plot

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud2)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
df1=df1.astype(np.int64)

# %%
#To copy the dataframe
df_max_scaled = df1.copy()

# applying normalization techniques
for column in df_max_scaled.columns:
    df_max_scaled[column] = df_max_scaled[column]  / df_max_scaled[column].abs().max()

# printing normalized data
display(df_max_scaled)
# Out:
#    Twitter Followers  Twitter Likes  Twitter ReTweets  Popularity  \
# 0           1.000000       1.000000          1.000000     1.00000
# 1           0.726423       0.004613          0.016963     0.86747
#
#    Youtube Views  Youtube Subscribers  Youtube videos
# 0       1.000000             1.000000        0.329177
# 1       0.088446             0.122816        1.000000

# %%
num_score = (df_max_scaled.mean().mean()*10)*0.875
num_score
# Out:
# 5.7224420405693

# %%
df_gen=df['Genre'].astype(str)
df_gen
# Out:
# 0                    ['dance pop', 'pop', 'viral pop']
# 1    ['big room', 'dance pop', 'dutch house', 'edm'...
# Name: Genre, dtype: object

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
doc_vec = tfidf_vectorizer.fit_transform(df_gen)

# %%
df2 = pd.DataFrame(doc_vec.toarray().transpose(),index=tfidf_vectorizer.get_feature_names())

# %%
df2.columns = df2.columns
genre_score = (pd.DataFrame.mean(df2).mean()*10)*0.125
genre_score
# Out:
# 0.2278810302761728

# %%
similarity_score=num_score + genre_score
similarity_score
# Out:
# 5.950323070845473
